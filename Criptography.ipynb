# %%
cypher_text = """ LYMBXJXKBBKBJPJJBBKBJPZPHYXNJKGOLOGPIEYHKBI
                  XJSOEPVJBPMBXJEPONKBIEJGJOEATPYOXUOBAJPTJLK
                  JDXGYLOEPKLKAKODKBPJDDKIJBAJXOPOGAKJBAJAYVS
                  MPJEGAKJBAJOSSDKJXVOPTJVOPKAGOBXEYFYPKAGLME
                  PTJEVYEJXNJVOKBPOKBGODOEIJBJPHYENYLKBXMGPEZ
                  SOEPBJEGPTEYMITPTJOHOEXHKBBKBINJHYENSEYIEOV
                  VJOBXPTEYMITYMEEJGJOEATAYDDOFYEOPKYBGPTJXJS
                  OEPVJBPSEYUKXJGJXMAOPKYBPTEYMITYBJFOATJDYEG
                  SEYIEOVVJOBXPHYVOGPJEGSEYIEOVVJGEJGJOEATOPP
                  TJXJSOEPVJBPYLXOPOGAKJBAJOBXNBYHDJXIJJBIKBJ
                  JEKBIGSOBGPTJXKGAKSDKBJGOBXKBPJELOAJGYLOEPK
                  LKAKODKBPJDDKIJBAJXOPOGAKJBAJAYVSMPJEGAKJBA
                  JOBXOSSDKJXVOPTJVOPKAGHJXJUJDYSBJHPYYDGOBXV
                  JPTYXYDYIKJGPYOXUOBAJPTJGJLKJDXGOPPTJGOVJPK
                  VJHJAYDDOFYEOPJHKPTOHKXJEOBIJYLKBGPKPMPJGFY
                  PTHKPTKBOBXYMPGKXJYLVOOGPEKATPMBKUJEGKPZOBX
                  HYENYBXKUJEGJOSSDKAOPKYBGKBADMXKBIKBPTJLKJD
                  XGYLTJODPTOBXVJXKAKBJDYIKGPKAGFKYDYIZOEPSTZ
                  GKAGAZFJEGJAMEKPZBJMEYGAKJBAJOBXJXMAOPKYB  """

# %%
def substitute_characters(text, substitutions):
    translation_table = str.maketrans(substitutions)

    substituted_text = text.translate(translation_table)

    return substituted_text

# %%
import random
import string
import pandas as pd

def create_random_substitutions_dict(text, previous_dict):
    english_alphabet = set(string.ascii_uppercase)

    remaining_letters = english_alphabet - set(previous_dict.keys())

    text_letters = [char for char in text.upper() if char.isalpha()]

    shuffled_letters = list(remaining_letters)
    random.shuffle(shuffled_letters)

    new_substitutions = dict(zip([char for char in text_letters if char not in previous_dict], shuffled_letters))

    updated_dict = {**previous_dict, **new_substitutions}

    return updated_dict

# %%
pip install english-words
# Out:
# Requirement already satisfied: english-words in c:\users\alvaro\appdata\local\programs\python\python311\lib\site-packages (2.0.1)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import csv
with open('word-freq-top5000.csv', 'r') as csv_file:
    reader = csv.DictReader(csv_file)
    word_set = set(row['Word'] for row in reader)
    
print(len(word_set))
# Out:
# 4354

# %%
def contains_english_word(text):
    lowercased_text = text.lower()

    if lowercased_text in set(word_set):
        return True

    for word in word_set:
        if word in lowercased_text and len(word) > 4:
            return True, word

    return False, None

def is_english_word(word):
    return word.lower() in set(word_set)

def count_subwords(text, word_len):
    found_words = []
    text_len = len(text)

    i = 0
    while i <= text_len - word_len:
        substring = text[i:i+word_len]

        if is_english_word(substring):
            found_words.append(substring)
            text = text[:i] + text[i+word_len:]  # Remove the found word from the text
            text_len = len(text)  # Update the text length
        else:
            i += 1  

    return found_words, text


input_text = "deibdeboidhbhowareyoukejljl"
word_length = 3
result, text = count_subwords(input_text, word_length)

print(result, text)
# Out:
# ['how', 'are', 'you'] deibdeboidhbkejljl

# %%
fitness_dict = {3:1, 4:10, 5:50, 6:100, 7:100, 8:100, 9:100, 10:100, 11:100}
def fitness(individual, text):
    deciphered_text = substitute_characters(text, individual)
    text = deciphered_text
    fitness = 0
    total_words = []

    for i in range(10, 2, -1):
        found_words, remaining_text = count_subwords(text, i)
        fitness += len(found_words) * fitness_dict[i]
        text = remaining_text
        total_words.extend(found_words)
        
    return fitness, total_words

# test_text = "OLSSVOVD"
# test_dict = {'O':'H', 'L':'E', 'S':'L','V':'O','D':'W'}
# print(fitness(test_dict, test_text))

# %%
def crossover(generation, size, text):
    parents = generation[:parents_size]
    new_gen = []
    for i in range(size):
        p = random.random() 
        if p < 0.7:
            first_individual = random.choice(parents)
            second_individual = random.choice(parents)

        else:
            first_individual = create_random_substitutions_dict(text, {})
            second_individual = create_random_substitutions_dict(text, {})
        new_individual = {}
        for key in first_individual.keys():
            new_individual[key] = random.choice([first_individual[key], second_individual[key]])
        new_gen.append(new_individual)
    return new_gen


def apply_mutation(generation):
    for individual in generation:
        p = random.random()  
        if p < mutation_rate:
            random_key = random.choice(list(individual.keys()))
            individual[random_key] = random.choice(string.ascii_uppercase)
    return generation


size = 100
parents_size = 20
mutation_rate = 0.5
small_cypher_text = "GKAGAZFJEGJAMEKPZBJMEYGAKJBAJOBXJXMAOPKYB"

converged = False
best_dict = {}
curr_gen = [create_random_substitutions_dict(small_cypher_text, {}) for i in range(size)]
max_fitness = 0
curr_fitness = 0
i = 0
tot_gen = 0

while not converged:
    sorted_gen = sorted(curr_gen, key=lambda x: fitness(x, small_cypher_text), reverse=True)
    curr_gen = apply_mutation(crossover(sorted_gen, size, small_cypher_text))
    curr_fitness, _ = fitness(curr_gen[0], small_cypher_text)
    i += 1
    tot_gen += 1
    for individual in sorted_gen[:3]:
        fit, total_words = fitness(individual, small_cypher_text)
        decyphered_text = substitute_characters(small_cypher_text, individual)
        print(f"Fitness: {fit}, Deciphered text: {decyphered_text}, Words found:{total_words}")

    print(f"Generations: {tot_gen}")
    if(curr_fitness > max_fitness):
        max_fitness = curr_fitness
        best_dict = sorted_gen[0]
        print(f"Best dict: {best_dict}")
        i = 0
    if(i == 30):
        curr_gen = [create_random_substitutions_dict(small_cypher_text, {}) for i in range(size)]
# Out:
# Fitness: 11, Deciphered text: FCMFMWHATFAMVTCLWNAVTYFMCANMAONXAXVMOLCYN, Words found:['WHAT', 'CAN']
# Fitness: 11, Deciphered text: WHAWAYIRGWRAUGHSYCRUGQWAHRCAROCXRXUAOSHQC, Words found:['AWAY', 'CAR']
# Fitness: 10, Deciphered text: VRFVFZGSYVSFNYROZLSNYAVFRSLFSOLXSXNFOORAL, Words found:['ORAL']
# Generations: 1
# Fitness: 12, Deciphered text: FPLFLWHATFALCTPNWNACTKFLPANLAONXAXCLONPKN, Words found:['WHAT', 'ACT', 'PAN']
# Fitness: 11, Deciphered text: OMRORBGHOOHRXOMDBLHXONORMHLRHOLXHXXRODMNL, Words found:['NORM', 'ROD']
# Fitness: 11, Deciphered text: LQDLDIWEALEDNAQMINENAFLDQENDEONXEXNDOMQFN, Words found:['MINE', 'END']
# Generations: 2
# Best dict: {'G': 'F', 'K': 'P', 'A': 'L', 'Z': 'W', 'F': 'H', 'J': 'A', 'E': 'T', 'M': 'C', 'P': 'N', 'B': 'N', 'Y': 'K'}
# Fitness: 12, Deciphered text: ZCLZLWHATZALCTCNWNACTGZLCANLAONXAXCLONCGN, Words found:['WHAT', 'ACT', 'CAN']
# Fitness: 12, Deciphered text: LBTLTIIETLETVTBPINEVTYLTBENTEONXEXVTOPBYN, Words found:['PINE', 'LET', 'TOP']
# Fitness: 11, Deciphered text: BZYBYTEXTBXYOTZUTDXOTCBYZXDYXODXXXOYOUZCD, Words found:['TEXT', 'YOU']
# Generations: 3
# Fitness: 50, Deciphered text: VBTVTFWEAVETHABKFWEHAFVTBEWTEOWXEXHTOKBFW, Words found:['WEAVE']
# Fitness: 13, Deciphered text: SBTSTIJETSETJTBPINEJTISTBENTEONXEXJTOPBIN, Words found:['PINE', 'JET', 'SET', 'TOP']
# Fitness: 11, Deciphered text: FCLFLWHATFALCTCKWWACTYFLCAWLAOWXAXCLOKCYW, Words found:['WHAT', 'ACT']
# Generations: 4
# Fitness: 61, Deciphered text: NRTNTDZZANZTFAREDHZFAINTRZHTZOHXZXFTOERIH, Words found:['FAINT', 'FARE', 'TOE']
# Fitness: 50, Deciphered text: VBNVNZWEAVENNABMZXENAFVNBEXNEOXXEXNNOMBFX, Words found:['WEAVE']
# Fitness: 50, Deciphered text: VBTVTFWEAVETHABKFWEHAFVTBEWTEOWXEXHTOKBFW, Words found:['WEAVE']
# Generations: 5
# Fitness: 50, Deciphered text: VBTVTFWEAVETHABKFHEHAKVTBEHTEOHXEXHTOKBKH, Words found:['WEAVE']
# Fitness: 50, Deciphered text: VBTVTZWEAVETNABMZHENAIVTBEHTEOHXEXNTOMBIH, Words found:['WEAVE']
# Fitness: 50, Deciphered text: VBNVNZWEAVENJABMZXEJAIVNBEXNEOXXEXJNOMBIX, Words found:['WEAVE']
# Generations: 6
# Fitness: 51, Deciphered text: VMNVNZWEAVENJAMMZXEJAIVNMEXNEOXXEXJNOMMIX, Words found:['WEAVE', 'MIX']
# Fitness: 50, Deciphered text: VBTVTZWEAVETHABMZHEHAIVTBEHTEOHXEXHTOMBIH, Words found:['WEAVE']
# Fitness: 22, Deciphered text: SDTSTBZELSETNLDPBNENLISTDENTEONXEXNTOPDIN, Words found:['ELSE', 'LIST', 'END', 'TOP']
# Generations: 7
# Fitness: 52, Deciphered text: VRNVNZWEAVENYARMZHEYAIVNREHNEOHXEXYNOMRIH, Words found:['WEAVE', 'ARM', 'HEY']
# Fitness: 51, Deciphered text: VMNVNZWEAVENYAMMZXEYAIVNMEXNEOXXEXYNOMMIX, Words found:['WEAVE', 'MIX']
# Fitness: 51, Deciphered text: VMIVIZWEAVEIYAMOZXEYAIVIMEXIEOXXEXYIOOMIX, Words found:['WEAVE', 'MIX']
# Generations: 8
# Best dict: {'G': 'V', 'K': 'R', 'A': 'N', 'Z': 'Z', 'F': 'W', 'J': 'E', 'E': 'A', 'M': 'Y', 'P': 'M', 'B': 'H', 'Y': 'I'}
# Fitness: 51, Deciphered text: VMIVIZWEAVEIYAMOZXEYAIVIMEXIEOXXEXYIOOMIX, Words found:['WEAVE', 'MIX']
# Fitness: 51, Deciphered text: VMNVNZWEAVENNAMMZXENAIVNMEXNEOXXEXNNOMMIX, Words found:['WEAVE', 'MIX']
# Fitness: 51, Deciphered text: VMNVNZWEAVENYAMMZXEYAIVNMEXNEOXXEXYNOMMIX, Words found:['WEAVE', 'MIX']
# Generations: 9
# Fitness: 51, Deciphered text: VAIVIZWEAVEIYAAOZXEYAIVIAEXIEOXXEXYIOOAIX, Words found:['WEAVE', 'VIA']
# Fitness: 51, Deciphered text: VMNVNZWEAVENYAMMZXEYAIVNMEXNEOXXEXYNOMMIX, Words found:['WEAVE', 'MIX']
# Fitness: 51, Deciphered text: VMIVIOWEAVEIYAMOOXEYAIVIMEXIEOXXEXYIOOMIX, Words found:['WEAVE', 'MIX']
# Generations: 10
# Fitness: 60, Deciphered text: VYNVNIWEAVENJAYMINEJAIVNYENNEONXEXJNOMYIN, Words found:['WEAVE', 'MINE']
# Fitness: 52, Deciphered text: VMNVNDWEAVENDAMMDXEDAIVNMEXNEOXXEXDNOMMIX, Words found:['WEAVE', 'DAM', 'MIX']
# Fitness: 51, Deciphered text: VMIVITWEAVEIEAMITXEEANVIMEXIEOXXEXEIOIMNX, Words found:['WEAVE', 'TIE']
# Generations: 11
# Fitness: 70, Deciphered text: VONVNIWEAVENEAOMINEEAIVNOENNEONXEXENOMOIN, Words found:['WEAVE', 'NINE', 'MINE']
# Fitness: 60, Deciphered text: VMNVNZWEAVENFAMEZNEFAIVNMENNEONXEXFNOEMIN, Words found:['WEAVE', 'FAME']
# Fitness: 52, Deciphered text: VMNVNZWEAVENDAMMZXEDAIVNMEXNEOXXEXDNOMMIX, Words found:['WEAVE', 'DAM', 'MIX']
# Generations: 12
# Fitness: 100, Deciphered text: VUNVNIWEAVENDAUMIXEDAIVNUEXNEOXXEXDNOMUIX, Words found:['WEAVE', 'MIXED']
# Fitness: 100, Deciphered text: KMNKNZWEAKENNAMMZXENAUKNMEXNEOXXEXNNOMMUX, Words found:['WEAKEN']
# Fitness: 70, Deciphered text: VONVNIWEAVENEAOMINEEAIVNOENNEONXEXENOMOIN, Words found:['WEAVE', 'NINE', 'MINE']
# Generations: 13
# Fitness: 102, Deciphered text: VMNVNIWEAVENDAMMIXEDAIVNMEXNEOXXEXDNOMMIX, Words found:['WEAVE', 'MIXED', 'DAM', 'MIX']
# Fitness: 101, Deciphered text: KMNKNZWEAKENNAMMZXENAIKNMEXNEOXXEXNNOMMIX, Words found:['WEAKEN', 'MIX']
# Fitness: 101, Deciphered text: KMNKNZWEAKENNAMMZXENAIKNMEXNEOXXEXNNOMMIX, Words found:['WEAKEN', 'MIX']
# Generations: 14
# Fitness: 152, Deciphered text: KMNKNIWEAKENDAMMIXEDAIKNMEXNEOXXEXDNOMMIX, Words found:['WEAKEN', 'MIXED', 'DAM', 'MIX']
# Fitness: 102, Deciphered text: VMNVNIWEAVENDAMMIXEDAIVNMEXNEOXXEXDNOMMIX, Words found:['WEAVE', 'MIXED', 'DAM', 'MIX']
# Fitness: 102, Deciphered text: VMNVNIWEAVENDAMMIXEDAIVNMEXNEOXXEXDNOMMIX, Words found:['WEAVE', 'MIXED', 'DAM', 'MIX']
# Generations: 15
# Fitness: 152, Deciphered text: KMNKNIWEAKENDAMMIXEDAIKNMEXNEOXXEXDNOMMIX, Words found:['WEAKEN', 'MIXED', 'DAM', 'MIX']
# Fitness: 152, Deciphered text: KMNKNIWEAKENDAMMIXEDAIKNMEXNEOXXEXDNOMMIX, Words found:['WEAKEN', 'MIXED', 'DAM', 'MIX']
# Fitness: 152, Deciphered text: KMNKNIWEAKENDAMMIXEDAIKNMEXNEOXXEXDNOMMIX, Words found:['WEAKEN', 'MIXED', 'DAM', 'MIX']
# Generations: 16
# Best dict: {'G': 'K', 'K': 'M', 'A': 'N', 'Z': 'I', 'F': 'W', 'J': 'E', 'E': 'A', 'M': 'D', 'P': 'M', 'B': 'X', 'Y': 'I'}
# Fitness: 152, Deciphered text: KMNKNIWEAKENDAMMIXEDAIKNMEXNEOXXEXDNOMMIX, Words found:['WEAKEN', 'MIXED', 'DAM', 'MIX']
# Fitness: 152, Deciphered text: KMNKNIWEAKENDAMMIXEDAIKNMEXNEOXXEXDNOMMIX, Words found:['WEAKEN', 'MIXED', 'DAM', 'MIX']
# Fitness: 152, Deciphered text: KMNKNIWEAKENDAMMIXEDAIKNMEXNEOXXEXDNOMMIX, Words found:['WEAKEN', 'MIXED', 'DAM', 'MIX']
# Generations: 17
# Fitness: 152, Deciphered text: KMNKNIWEAKENDAMMIXEDAIKNMEXNEOXXEXDNOMMIX, Words found:['WEAKEN', 'MIXED', 'DAM', 'MIX']
# Fitness: 152, Deciphered text: KMNKNIWEAKENDAMMIXEDAIKNMEXNEOXXEXDNOMMIX, Words found:['WEAKEN', 'MIXED', 'DAM', 'MIX']
# Fitness: 152, Deciphered text: KMNKNIWEAKENDAMMIXEDAIKNMEXNEOXXEXDNOMMIX, Words found:['WEAKEN', 'MIXED', 'DAM', 'MIX']
# Generations: 18
# Best dict: {'G': 'K', 'K': 'M', 'A': 'N', 'Z': 'I', 'F': 'W', 'J': 'E', 'E': 'A', 'M': 'D', 'P': 'M', 'B': 'X', 'Y': 'I'}
# Fitness: 152, Deciphered text: KMNKNIWEAKENDAMMIXEDAIKNMEXNEOXXEXDNOMMIX, Words found:['WEAKEN', 'MIXED', 'DAM', 'MIX']
# Fitness: 152, Deciphered text: KMNKNIWEAKENDAMMIXEDAIKNMEXNEOXXEXDNOMMIX, Words found:['WEAKEN', 'MIXED', 'DAM', 'MIX']
# Fitness: 152, Deciphered text: KMNKNIWEAKENDAMMIXEDAIKNMEXNEOXXEXDNOMMIX, Words found:['WEAKEN', 'MIXED', 'DAM', 'MIX']
# Generations: 19
# Fitness: 160, Deciphered text: KMNKNIWEAKENDAMMIXEDARKNMEXNEOXXEXDNOMMRX, Words found:['WEAKEN', 'MIXED', 'MARK']
# Fitness: 152, Deciphered text: KMNKNIWEAKENDAMMIXEDAIKNMEXNEOXXEXDNOMMIX, Words found:['WEAKEN', 'MIXED', 'DAM', 'MIX']
# Fitness: 152, Deciphered text: KMNKNIWEAKENDAMMIXEDAIKNMEXNEOXXEXDNOMMIX, Words found:['WEAKEN', 'MIXED', 'DAM', 'MIX']
# Generations: 20
# Fitness: 160, Deciphered text: KMNKNIWEAKENDAMMIXEDARKNMEXNEOXXEXDNOMMRX, Words found:['WEAKEN', 'MIXED', 'MARK']
# Fitness: 160, Deciphered text: KENKNIWEAKENDAEMIXEDAIKNEEXNEOXXEXDNOMEIX, Words found:['WEAKEN', 'MIXED', 'KNEE']
# Fitness: 152, Deciphered text: KMNKNIWEAKENDAMMIXEDAIKNMEXNEOXXEXDNOMMIX, Words found:['WEAKEN', 'MIXED', 'DAM', 'MIX']
# Generations: 21
# Fitness: 160, Deciphered text: KMNKNIWEAKENDAMMIXEDARKNMEXNEOXXEXDNOMMRX, Words found:['WEAKEN', 'MIXED', 'MARK']
# Fitness: 160, Deciphered text: KENKNIWEAKENDAEMIXEDAIKNEEXNEOXXEXDNOMEIX, Words found:['WEAKEN', 'MIXED', 'KNEE']
# Fitness: 160, Deciphered text: KENKNIWEAKENDAEMIXEDAIKNEEXNEOXXEXDNOMEIX, Words found:['WEAKEN', 'MIXED', 'KNEE']
# Generations: 22
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 160, Deciphered text: KMNKNIWEAKENDAMMIXEDARKNMEXNEOXXEXDNOMMRX, Words found:['WEAKEN', 'MIXED', 'MARK']
# Generations: 23
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 160, Deciphered text: KENKNIWEAKENDAEMIXEDAIKNEEXNEOXXEXDNOMEIX, Words found:['WEAKEN', 'MIXED', 'KNEE']
# Fitness: 160, Deciphered text: KENKNIWEAKENDAEMIXEDAIKNEEXNEOXXEXDNOMEIX, Words found:['WEAKEN', 'MIXED', 'KNEE']
# Generations: 24
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 160, Deciphered text: KENKNIWEAKENDAEMIXEDAIKNEEXNEOXXEXDNOMEIX, Words found:['WEAKEN', 'MIXED', 'KNEE']
# Fitness: 160, Deciphered text: KENKNIWEAKENDAEMIXEDAIKNEEXNEOXXEXDNOMEIX, Words found:['WEAKEN', 'MIXED', 'KNEE']
# Generations: 25
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Generations: 26
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Generations: 27
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Generations: 28
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Generations: 29
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Generations: 30
# Best dict: {'G': 'K', 'K': 'E', 'A': 'N', 'Z': 'I', 'F': 'W', 'J': 'E', 'E': 'A', 'M': 'D', 'P': 'M', 'B': 'X', 'Y': 'R'}
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Generations: 31
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Generations: 32
# Best dict: {'G': 'K', 'K': 'E', 'A': 'N', 'Z': 'I', 'F': 'W', 'J': 'E', 'E': 'A', 'M': 'D', 'P': 'M', 'B': 'X', 'Y': 'R'}
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Generations: 33
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Generations: 34
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Generations: 35
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Generations: 36
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Generations: 37
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Generations: 38
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Generations: 39
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Generations: 40
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Generations: 41
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Generations: 42
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Generations: 43
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Generations: 44
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Generations: 45
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDARKNEEXNEOXXEXDNOMERX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAR']
# Generations: 46
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Generations: 47
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Generations: 48
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Generations: 49
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Generations: 50
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Generations: 51
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Generations: 52
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Generations: 53
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Generations: 54
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Generations: 55
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Generations: 56
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Generations: 57
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Generations: 58
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Generations: 59
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Generations: 60
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Generations: 61
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Fitness: 161, Deciphered text: KENKNIWEAKENDAEMIXEDATKNEEXNEOXXEXDNOMETX, Words found:['WEAKEN', 'MIXED', 'KNEE', 'EAT']
# Generations: 62
# Fitness: 10, Deciphered text: LWSLSQPOULOSIUWTQNOIUGLSWONSOONXOXISOTWGN, Words found:['SOON']
# Fitness: 10, Deciphered text: BTPBPDZSQBSPNQTEDVSNQFBPTSVPSOVXSXNPOETFV, Words found:['POET']
# Fitness: 10, Deciphered text: ZROZOLWVAZVODARULYVDASZORVYOVOYXVXDOOURSY, Words found:['OURS']
# Generations: 63
# Fitness: 50, Deciphered text: TSMTMVJBXTBMCXSUVGBCXETMSBGMBOGXBXCMOUSEG, Words found:['MOUSE']
# Fitness: 12, Deciphered text: ADCACTZYQAYCDQDLTOYDQPACDYOCYOOXYXDCOLDPO, Words found:['COLD', 'ACT', 'TOY']
# Fitness: 11, Deciphered text: LWSLSEPOULOSIUWTENOIUGLSWONSOONXOXISOTWGN, Words found:['SOON', 'TEN']
# Generations: 64
# Fitness: 100, Deciphered text: FTCFCPOKSFKCRSTTPNKRSOFCTKNCKONXKXRCOTTON, Words found:['COTTON']
# Fitness: 52, Deciphered text: TSMTMKPBETBMCESUKWBCEETMSBWMBOWXBXCMOUSEW, Words found:['MOUSE', 'BET', 'BOW']
# Fitness: 20, Deciphered text: NDCNCHINQNNCWQDLHONWQONCDNOCNOOXNXWCOLDOO, Words found:['CHIN', 'COLD']
# Generations: 65
# Fitness: 52, Deciphered text: TSMTMQPBETBMCESUQWBCEETMSBWMBOWXBXCMOUSEW, Words found:['MOUSE', 'BET', 'BOW']
# Fitness: 30, Deciphered text: JDTJTLOOKJOTIKDDLNOIKSJTDONTOONXOXITODDSN, Words found:['LOOK', 'ONTO', 'ODDS']
# Fitness: 23, Deciphered text: LWTLTEGODLOTEDWHENOEDGLTWONTOONXOXETOHWGN, Words found:['WHEN', 'ONTO', 'EGO', 'LOT', 'TWO']
# Generations: 66
# Fitness: 51, Deciphered text: TSMTMQOBETBMRESUQNBREETMSBNMBONXBXRMOUSEN, Words found:['MOUSE', 'BET']
# Fitness: 33, Deciphered text: TSTTTHPOETOTRESSHNOREOTTSONTOONXOXRTOSSON, Words found:['POET', 'ONTO', 'TOSS', 'HOT', 'NOR', 'SON']
# Fitness: 20, Deciphered text: LTRLRTINULNRDUTPTENDUXLRTNERNOEXNXDROPTXE, Words found:['TEND', 'DROP']
# Generations: 67
# Fitness: 51, Deciphered text: TSMTMHIBETBMRESUHDBREETMSBDMBODXBXRMOUSED, Words found:['MOUSE', 'BET']
# Fitness: 21, Deciphered text: IDSISHOOKIOSWKDTHNOWKGISDONSOONXOXWSOTDGN, Words found:['HOOK', 'SOON', 'NOW']
# Fitness: 20, Deciphered text: LTCLCFINELNCDETSFNNDEXLCTNNCNONXNXDCOSTXN, Words found:['FINE', 'COST']
# Generations: 68
# Fitness: 50, Deciphered text: JRSJSHINEJNSWERLHONWEOJSRNOSNOOXNXWSOLROO, Words found:['SHINE']
# Fitness: 21, Deciphered text: XSAXATONEXNARESTTENREXXASNEANOEXNXRAOTSXE, Words found:['TONE', 'REST', 'TEN']
# Fitness: 21, Deciphered text: TSDTDFINETNDRESTFNNREETDSNNDNONXNXRDOTSEN, Words found:['FINE', 'REST', 'DOT']
# Generations: 69
# Fitness: 60, Deciphered text: JRSJSHINEJNSRERTHENREOJSRNESNOEXNXRSOTROE, Words found:['SHINE', 'THEN']
# Fitness: 50, Deciphered text: TASTSHINETNSWEALHONWEOTSANOSNOOXNXWSOLAOO, Words found:['SHINE']
# Fitness: 21, Deciphered text: XSDXDZONEXNDWESTZINWEOXDSNIDNOIXNXWDOTSOI, Words found:['ZONE', 'WEST', 'DOT']
# Generations: 70
# Fitness: 60, Deciphered text: JRSJSHINEJNSRERTHENREOJSRNESNOEXNXRSOTROE, Words found:['SHINE', 'THEN']
# Fitness: 60, Deciphered text: LASLSHINELNSREALHNNREOLSANNSNONXNXRSOLAON, Words found:['SHINE', 'REAL']
# Fitness: 50, Deciphered text: LWSLSHINELNSWEWLHONWEGLSWNOSNOOXNXWSOLWGO, Words found:['SHINE']
# Generations: 71
# Fitness: 60, Deciphered text: LASLSHINELNSREALHNNREOLSANNSNONXNXRSOLAON, Words found:['SHINE', 'REAL']
# Fitness: 60, Deciphered text: TASTSHINETNSREALHNNREOTSANNSNONXNXRSOLAON, Words found:['SHINE', 'REAL']
# Fitness: 60, Deciphered text: TASTSHINETNSREALHNNREXTSANNSNONXNXRSOLAXN, Words found:['SHINE', 'REAL']
# Generations: 72
# Fitness: 70, Deciphered text: TASTSHINETNSSEALHNNSEATSANNSNONXNXSSOLAAN, Words found:['SHINE', 'SEAL', 'SEAT']
# Fitness: 61, Deciphered text: TASTSMLOETOSREALMNOREOTSAONSOONXOXRSOLAON, Words found:['REALM', 'SOON', 'NOR']
# Fitness: 60, Deciphered text: XASXSHINEXNSREALHNNREOXSANNSNONXNXRSOLAON, Words found:['SHINE', 'REAL']
# Generations: 73
# Fitness: 70, Deciphered text: LASLSHINELNSREALHNNREALSANNSNONXNXRSOLAAN, Words found:['SHINE', 'REAL', 'REAL']
# Fitness: 62, Deciphered text: TASTSHIOETOSDEATHNODEXTSAONSOONXOXDSOTAXN, Words found:['DEATH', 'SOON', 'NOD', 'TAX']
# Fitness: 61, Deciphered text: MASMSHINEMNSSEALHNNSEAMSANNSNONXNXSSOLAAN, Words found:['SHINE', 'SEAL', 'SEA']
# Generations: 74
# Fitness: 101, Deciphered text: TASTSHINETNSDEATHNNDEXTSANNSNONXNXDSOTAXN, Words found:['SHINE', 'DEATH', 'TAX']
# Fitness: 70, Deciphered text: LASLSHINELNSSEALHNNSEALSANNSNONXNXSSOLAAN, Words found:['SHINE', 'SEAL', 'SEAL']
# Fitness: 70, Deciphered text: LASLSHINELNSREALHONREALSANOSNOOXNXRSOLAAO, Words found:['SHINE', 'REAL', 'REAL']
# Generations: 75
# Fitness: 101, Deciphered text: TASTSHINETNSDEATHMNDEATSANMSNOMXNXDSOTAAM, Words found:['SHINE', 'DEATH', 'EAT']
# Fitness: 70, Deciphered text: TASTSHINETNSSEALHNNSEATSANNSNONXNXSSOLAAN, Words found:['SHINE', 'SEAL', 'SEAT']
# Fitness: 70, Deciphered text: LASLSHINELNSSEALHNNSEALSANNSNONXNXSSOLAAN, Words found:['SHINE', 'SEAL', 'SEAL']
# Generations: 76
# Fitness: 101, Deciphered text: TASTSHINETNSDEATHMNDEATSANMSNOMXNXDSOTAAM, Words found:['SHINE', 'DEATH', 'EAT']
# Fitness: 72, Deciphered text: TASTSHINETNSREALHDNREATSANDSNODXNXRSOLAAD, Words found:['SHINE', 'REAL', 'SAND', 'EAT', 'NOD']
# Fitness: 70, Deciphered text: TASTSHINETNSSEALHNNSEATSANNSNONXNXSSOLAAN, Words found:['SHINE', 'SEAL', 'SEAT']
# Generations: 77
# Fitness: 103, Deciphered text: SASSSHINESNSDEATHONDEASSANOSNOOXNXDSOTAAO, Words found:['SHINE', 'DEATH', 'ASS', 'SON', 'ASS']
# Fitness: 72, Deciphered text: TOSTSHINETNSSEOLHDNSEATSONDSNODXNXSSOLOAD, Words found:['SHINE', 'SEAT', 'LOAD', 'SON', 'NOD']
# Fitness: 71, Deciphered text: TOSTSHINETNSSEOLHNNSEATSONNSNONXNXSSOLOAN, Words found:['SHINE', 'SEAT', 'LOAN', 'SON']
# Generations: 78
# Fitness: 101, Deciphered text: TASTSHINETNSTEALHNNTEATSANNSNONXNXTSOLAAN, Words found:['SHINE', 'STEAL', 'TEA']
# Fitness: 101, Deciphered text: JASJSHINEJNSDEATHYNDEAJSANYSNOYXNXDSOTAAY, Words found:['SHINE', 'DEATH', 'ANY']
# Fitness: 72, Deciphered text: TASTSHINETNSSEAEHDNSEATSANDSNODXNXSSOEAAD, Words found:['SHINE', 'SEAT', 'SAND', 'SEA', 'NOD']
# Generations: 79
# Fitness: 101, Deciphered text: TASTSHINETNSTEALHZNTEATSANZSNOZXNXTSOLAAZ, Words found:['SHINE', 'STEAL', 'TEA']
# Fitness: 101, Deciphered text: TASTSHINETNSTEALHNNTEATSANNSNONXNXTSOLAAN, Words found:['SHINE', 'STEAL', 'TEA']
# Fitness: 81, Deciphered text: TASTSHINETNSSEALHDNSEATSANDSNODXNXSSOLAAD, Words found:['SHINE', 'SEAL', 'SEAT', 'SAND', 'NOD']
# Generations: 80
# Fitness: 101, Deciphered text: TASTSHINETNSTEALHNNTEATSANNSNONXNXTSOLAAN, Words found:['SHINE', 'STEAL', 'TEA']
# Fitness: 101, Deciphered text: TASTSHINETNSTEALHNNTEATSANNSNONXNXTSOLAAN, Words found:['SHINE', 'STEAL', 'TEA']
# Fitness: 101, Deciphered text: TASTSHINETNSTEALHMNTEATSANMSNOMXNXTSOLAAM, Words found:['SHINE', 'STEAL', 'TEA']
# Generations: 81
# Fitness: 112, Deciphered text: TASTSHINETNSTEALHDNTEATSANDSNODXNXTSOLAAD, Words found:['SHINE', 'STEAL', 'SAND', 'TEA', 'NOD']
# Fitness: 112, Deciphered text: TASTSHINETNSTEALHDNTEATSANDSNODXNXTSOLAAD, Words found:['SHINE', 'STEAL', 'SAND', 'TEA', 'NOD']
# Fitness: 112, Deciphered text: TASTSHINETNSTEALHDNTEATSANDSNODXNXTSOLAAD, Words found:['SHINE', 'STEAL', 'SAND', 'TEA', 'NOD']
# Generations: 82
# Fitness: 112, Deciphered text: TASTSHINETNSTEALHDNTEATSANDSNODXNXTSOLAAD, Words found:['SHINE', 'STEAL', 'SAND', 'TEA', 'NOD']
# Fitness: 112, Deciphered text: DASDSHINEDNSTEALHDNTEADSANDSNODXNXTSOLAAD, Words found:['SHINE', 'STEAL', 'SAND', 'TEA', 'NOD']
# Fitness: 112, Deciphered text: TASTSHINETNSTEALHDNTEATSANDSNODXNXTSOLAAD, Words found:['SHINE', 'STEAL', 'SAND', 'TEA', 'NOD']
# Generations: 83
# Fitness: 112, Deciphered text: LASLSHINELNSTEALHDNTEALSANDSNODXNXTSOLAAD, Words found:['SHINE', 'STEAL', 'SAND', 'TEA', 'NOD']
# Fitness: 112, Deciphered text: TASTSHINETNSTEALHDNTEATSANDSNODXNXTSOLAAD, Words found:['SHINE', 'STEAL', 'SAND', 'TEA', 'NOD']
# Fitness: 112, Deciphered text: TASTSHINETNSTEALHDNTEATSANDSNODXNXTSOLAAD, Words found:['SHINE', 'STEAL', 'SAND', 'TEA', 'NOD']
# Generations: 84
# Fitness: 122, Deciphered text: OASOSHINEONSTEALHDNTEAOSANDSNODXNXTSOLAAD, Words found:['SHINE', 'STEAL', 'SOON', 'SAND', 'TEA', 'NOD']
# Fitness: 112, Deciphered text: LASLSHINELNSTEALHDNTEALSANDSNODXNXTSOLAAD, Words found:['SHINE', 'STEAL', 'SAND', 'TEA', 'NOD']
# Fitness: 112, Deciphered text: LASLSHINELNSTEALHDNTEALSANDSNODXNXTSOLAAD, Words found:['SHINE', 'STEAL', 'SAND', 'TEA', 'NOD']
# Generations: 85
# Fitness: 161, Deciphered text: TASTSHINETNSTEALHDNTERTSANDSNODXNXTSOLARD, Words found:['SHINE', 'STEAL', 'SOLAR', 'SAND', 'NOD']
# Fitness: 122, Deciphered text: OASOSHINEONSTEALHDNTEAOSANDSNODXNXTSOLAAD, Words found:['SHINE', 'STEAL', 'SOON', 'SAND', 'TEA', 'NOD']
# Fitness: 122, Deciphered text: OASOSHINEONSTEALHDNTEAOSANDSNODXNXTSOLAAD, Words found:['SHINE', 'STEAL', 'SOON', 'SAND', 'TEA', 'NOD']
# Generations: 86
# Fitness: 171, Deciphered text: OASOSHINEONSTEALHDNTEROSANDSNODXNXTSOLARD, Words found:['SHINE', 'STEAL', 'SOLAR', 'SOON', 'SAND', 'NOD']
# Fitness: 161, Deciphered text: LASLSHINELNSTEALHDNTERLSANDSNODXNXTSOLARD, Words found:['SHINE', 'STEAL', 'SOLAR', 'SAND', 'NOD']
# Fitness: 150, Deciphered text: TASTSHINETNSTEALHNNTERTSANNSNONXNXTSOLARN, Words found:['SHINE', 'STEAL', 'SOLAR']
# Generations: 87
# Fitness: 171, Deciphered text: OASOSHINEONSTEALHDNTEROSANDSNODXNXTSOLARD, Words found:['SHINE', 'STEAL', 'SOLAR', 'SOON', 'SAND', 'NOD']
# Fitness: 150, Deciphered text: LASLSHINELNSTEALHNNTERLSANNSNONXNXTSOLARN, Words found:['SHINE', 'STEAL', 'SOLAR']
# Fitness: 122, Deciphered text: OASOSHINEONSTEALHDNTEAOSANDSNODXNXTSOLAAD, Words found:['SHINE', 'STEAL', 'SOON', 'SAND', 'TEA', 'NOD']
# Generations: 88
# Fitness: 171, Deciphered text: OASOSHINEONSTEALHDNTEROSANDSNODXNXTSOLARD, Words found:['SHINE', 'STEAL', 'SOLAR', 'SOON', 'SAND', 'NOD']
# Fitness: 160, Deciphered text: OASOSHINEONSTEALHNNTEROSANNSNONXNXTSOLARN, Words found:['SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 150, Deciphered text: LASLSHINELNSTEALHNNTERLSANNSNONXNXTSOLARN, Words found:['SHINE', 'STEAL', 'SOLAR']
# Generations: 89
# Fitness: 210, Deciphered text: OASOSHINEONSTEALHENTEROSANESNOEXNXTSOLARE, Words found:['SHINE', 'STEAL', 'ENTER', 'SOLAR', 'SOON']
# Fitness: 171, Deciphered text: OASOSHINEONSTEALHDNTEROSANDSNODXNXTSOLARD, Words found:['SHINE', 'STEAL', 'SOLAR', 'SOON', 'SAND', 'NOD']
# Fitness: 171, Deciphered text: OASOSHINEONSTEALHDNTEROSANDSNODXNXTSOLARD, Words found:['SHINE', 'STEAL', 'SOLAR', 'SOON', 'SAND', 'NOD']
# Generations: 90
# Fitness: 210, Deciphered text: OASOSHINEONSTEALHENTEROSANESNOEXNXTSOLARE, Words found:['SHINE', 'STEAL', 'ENTER', 'SOLAR', 'SOON']
# Fitness: 171, Deciphered text: OASOSHINEONSTEALHDNTEROSANDSNODXNXTSOLARD, Words found:['SHINE', 'STEAL', 'SOLAR', 'SOON', 'SAND', 'NOD']
# Fitness: 171, Deciphered text: OASOSHINEONSTEALHDNTEROSANDSNODXNXTSOLARD, Words found:['SHINE', 'STEAL', 'SOLAR', 'SOON', 'SAND', 'NOD']
# Generations: 91
# Fitness: 210, Deciphered text: OASOSHINEONSTEALHENTEROSANESNOEXNXTSOLARE, Words found:['SHINE', 'STEAL', 'ENTER', 'SOLAR', 'SOON']
# Fitness: 210, Deciphered text: OASOSHINEONSTEALHENTEROSANESNOEXNXTSOLARE, Words found:['SHINE', 'STEAL', 'ENTER', 'SOLAR', 'SOON']
# Fitness: 210, Deciphered text: OASOSHINEONSTEALHENTEROSANESNOEXNXTSOLARE, Words found:['SHINE', 'STEAL', 'ENTER', 'SOLAR', 'SOON']
# Generations: 92
# Fitness: 210, Deciphered text: OASOSHINEONSTEALHENTEROSANESNOEXNXTSOLARE, Words found:['SHINE', 'STEAL', 'ENTER', 'SOLAR', 'SOON']
# Fitness: 210, Deciphered text: OASOSHINEONSTEALHENTEROSANESNOEXNXTSOLARE, Words found:['SHINE', 'STEAL', 'ENTER', 'SOLAR', 'SOON']
# Fitness: 210, Deciphered text: OASOSHINEONSTEALHENTEROSANESNOEXNXTSOLARE, Words found:['SHINE', 'STEAL', 'ENTER', 'SOLAR', 'SOON']
# Generations: 93
# Fitness: 210, Deciphered text: OASOSHINEONSTEALHENTEROSANESNOEXNXTSOLARE, Words found:['SHINE', 'STEAL', 'ENTER', 'SOLAR', 'SOON']
# Fitness: 210, Deciphered text: OASOSHINEONSTEALHENTEROSANESNOEXNXTSOLARE, Words found:['SHINE', 'STEAL', 'ENTER', 'SOLAR', 'SOON']
# Fitness: 210, Deciphered text: OASOSHINEONSTEALHENTEROSANESNOEXNXTSOLARE, Words found:['SHINE', 'STEAL', 'ENTER', 'SOLAR', 'SOON']
# Generations: 94
# Fitness: 210, Deciphered text: OASOSHINEONSTEALHENTEROSANESNOEXNXTSOLARE, Words found:['SHINE', 'STEAL', 'ENTER', 'SOLAR', 'SOON']
# Fitness: 210, Deciphered text: OASOSHINEONSTEALHENTEROSANESNOEXNXTSOLARE, Words found:['SHINE', 'STEAL', 'ENTER', 'SOLAR', 'SOON']
# Fitness: 210, Deciphered text: OASOSHINEONSTEALHENTEROSANESNOEXNXTSOLARE, Words found:['SHINE', 'STEAL', 'ENTER', 'SOLAR', 'SOON']
# Generations: 95
# Best dict: {'G': 'O', 'K': 'A', 'A': 'S', 'Z': 'H', 'F': 'I', 'J': 'N', 'E': 'E', 'M': 'T', 'P': 'L', 'B': 'E', 'Y': 'R'}
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 210, Deciphered text: OASOSHINEONSTEALHENTEROSANESNOEXNXTSOLARE, Words found:['SHINE', 'STEAL', 'ENTER', 'SOLAR', 'SOON']
# Fitness: 210, Deciphered text: OASOSHINEONSTEALHENTEROSANESNOEXNXTSOLARE, Words found:['SHINE', 'STEAL', 'ENTER', 'SOLAR', 'SOON']
# Generations: 96
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Generations: 97
# Best dict: {'G': 'O', 'K': 'A', 'A': 'S', 'Z': 'H', 'F': 'I', 'J': 'N', 'E': 'E', 'M': 'T', 'P': 'L', 'B': 'U', 'Y': 'R'}
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Generations: 98
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Generations: 99
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Generations: 100
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Generations: 101
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Generations: 102
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Generations: 103
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Generations: 104
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Generations: 105
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Generations: 106
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Generations: 107
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Generations: 108
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Generations: 109
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Generations: 110
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Generations: 111
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Generations: 112
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Generations: 113
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Generations: 114
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Fitness: 260, Deciphered text: OASOSHINEONSTEALHUNTEROSANUSNOUXNXTSOLARU, Words found:['HUNTER', 'SHINE', 'STEAL', 'SOLAR', 'SOON']
# Generations: 115
